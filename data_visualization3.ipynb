# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
train=pd.read_csv('/home/student/Documents/iris.csv')
train.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
train.shape
# Out:
# (150, 6)

# %%
train.get
# Out:
# <bound method NDFrame.get of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
train.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
train.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
train.sample(150)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 149  150            5.9           3.0            5.1           1.8
# 101  102            5.8           2.7            5.1           1.9
# 112  113            6.8           3.0            5.5           2.1
# 52    53            6.9           3.1            4.9           1.5
# 48    49            5.3           3.7            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 76    77            6.8           2.8            4.8           1.4
# 100  101            6.3           3.3            6.0           2.5
# 27    28            5.2           3.5            1.5           0.2
# 78    79            6.0           2.9            4.5           1.5
# 143  144            6.8           3.2            5.9           2.3
#
#              Species
# 149   Iris-virginica
# 101   Iris-virginica
# 112   Iris-virginica
# 52   Iris-versicolor
# 48       Iris-setosa
# ..               ...
# ...

# %%
train.drop(['PetalWidthCm'], axis=1, inplace=True)
print(train.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm      Species
# 0   1            5.1           3.5            1.4  Iris-setosa
# 1   2            4.9           3.0            1.4  Iris-setosa
# 2   3            4.7           3.2            1.3  Iris-setosa
# 3   4            4.6           3.1            1.5  Iris-setosa
# 4   5            5.0           3.6            1.4  Iris-setosa

# %%
train["SepalLengthCm"].fillna(train["SepalLengthCm"].mean(),inplace=True)

# %%
print(train["SepalWidthCm"].describe())
# Out:
# count    150.000000
# mean       3.054000
# std        0.433594
# min        2.000000
# 25%        2.800000
# 50%        3.000000
# 75%        3.300000
# max        4.400000
# Name: SepalWidthCm, dtype: float64

# %%
print(train["SepalWidthCm"].isna().sum())
# Out:
# 0

# %%
import seaborn as sns
train["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.countplot(x="SepalLengthCm",data=train)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='count'>

# %%
sns.countplot(x="SepalLengthCm",hue="Species",data=train)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='count'>

# %%
sns.countplot(x="SepalWidthCm",hue="Species",data=train)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='count'>

# %%
sns.countplot(x="PetalLengthCm",hue="Species",data=train)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 5))
plt.subplot(1,2,1)
sns.histplot(train["SepalLengthCm"], bins=20, kde=True)
plt.title("Distribution of Sepal length")
plt.xlabel("Sepal length (cm)")
plt.ylabel("Count")
plt.subplot(1,2,2)
sns.histplot(train["PetalLengthCm"], bins=20, kde=True)
plt.title("Distribution of Petal length")
plt.xlabel("Petal length (cm)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()
