# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/home/student/Downloads/Wine dataset.csv")
df
# Out:
#      class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
df_columns = ['class', 'Alcohol', 'Malic acid']
df_columns
# Out:
# ['class', 'Alcohol', 'Malic acid']

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
sns.kdeplot(df['class'])
# Out:
# <Axes: xlabel='class', ylabel='Density'>

# %%
color_dict = {1:'red', 2:'blue', 3:'green'}
sns.scatterplot(df['Alcohol'],   palette=color_dict)
# Out:
# <ipython-input-9-26336e604bdb>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(df['Alcohol'],   palette=color_dict)
# <Axes: ylabel='Alcohol'>

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop(['class'], axis = 1), df['class'], test_size=0.3, random_state = 0)

# %%
X_train
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 22     13.71        1.86  2.36               16.6        101           2.61
# 108    12.22        1.29  1.94               19.0         92           2.36
# 175    13.27        4.28  2.26               20.0        120           1.59
# 145    13.16        3.57  2.15               21.0        102           1.50
# 71     13.86        1.51  2.67               25.0         86           2.95
# ..       ...         ...   ...                ...        ...            ...
# 103    11.82        1.72  1.88               19.5         86           2.50
# 67     12.37        1.17  1.92               19.6         78           2.11
# 117    12.42        1.61  2.19               22.5        108           2.00
# 47     13.90        1.68  2.12               16.0        101           3.10
# 172    14.16        2.51  2.48               20.0         91           1.68
#
# ...

# %%
X_test
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 54     13.74        1.67  2.25               16.4        118           2.60
# 151    12.79        2.67  2.48               22.0        112           1.48
# 63     12.37        1.13  2.16               19.0         87           3.50
# 55     13.56        1.73  2.46               20.5        116           2.96
# 123    13.05        5.80  2.13               21.5         86           2.62
# 121    11.56        2.05  3.23               28.5        119           3.18
# 7      14.06        2.15  2.61               17.6        121           2.60
# 160    12.36        3.83  2.38               21.0         88           2.30
# 106    12.25        1.73  2.12               19.0         80           1.65
# 90     12.08        1.83  2.32               18.5         81           1.60
# 141    13.36        2.56  2.35               20.0         89           1.40
# ...

# %%
Y_train
# Out:
# 22     1
# 108    2
# 175    3
# 145    3
# 71     2
#       ..
# 103    2
# 67     2
# 117    2
# 47     1
# 172    3
# Name: class, Length: 124, dtype: int64

# %%
Y_test
# Out:
# 54     1
# 151    3
# 63     2
# 55     1
# 123    2
# 121    2
# 7      1
# 160    3
# 106    2
# 90     2
# 141    3
# 146    3
# 5      1
# 98     2
# 168    3
# 80     2
# 33     1
# 18     1
# 61     2
# 51     1
# 66     2
# 37     1
# 4      1
# 104    2
# 60     2
# 111    2
# 126    2
# 86     2
# 112    2
# 164    3
# 26     1
# 56     1
# 129    2
# 45     1
# 8      1
# 44     1
# 161    3
# 92     2
# 94     2
# 174    3
# 24     1
# 30     1
# 93     2
# 101    2
# 113    2
# 19     1
# 135    3
# 74     2
# 144    3
# 16     1
# 131    3
# 138    3
# 40     1
# 158    3
# Name: class, dtype: int64

# %%
X_train.shape
# Out:
# (124, 13)

# %%
X_test.shape
# Out:
# (54, 13)

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Correct Approach:
# Fit the scaler on the training data.
# Transform both the training and testing data using the same fitted scaler

# %%
scaler = MinMaxScaler()  # instance so ()
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_train_scaled
# Out:
#       Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0    0.720430    0.203782  0.537634           0.309278   0.336957
# 1    0.319892    0.084034  0.311828           0.432990   0.239130
# 2    0.602151    0.712185  0.483871           0.484536   0.543478
# 3    0.572581    0.563025  0.424731           0.536082   0.347826
# 4    0.760753    0.130252  0.704301           0.742268   0.173913
# ..        ...         ...       ...                ...        ...
# 119  0.212366    0.174370  0.279570           0.458763   0.173913
# 120  0.360215    0.058824  0.301075           0.463918   0.086957
# 121  0.373656    0.151261  0.446237           0.613402   0.413043
# 122  0.771505    0.165966  0.408602           0.278351   0.336957
# 123  0.841398    0.340336  0.602151           0.484536   0.228261
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0         0.543165    0.737003              0.250000         0.401899
# ...

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns = X_test.columns)
X_test_scaled
# Out:
#      Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0   0.728495    0.163866  0.478495           0.298969   0.521739
# 1   0.473118    0.373950  0.602151           0.587629   0.456522
# 2   0.360215    0.050420  0.430108           0.432990   0.184783
# 3   0.680108    0.176471  0.591398           0.510309   0.500000
# 4   0.543011    1.031513  0.413978           0.561856   0.173913
# 5   0.142473    0.243697  1.005376           0.922680   0.532609
# 6   0.814516    0.264706  0.672043           0.360825   0.554348
# 7   0.357527    0.617647  0.548387           0.536082   0.195652
# 8   0.327957    0.176471  0.408602           0.432990   0.108696
# 9   0.282258    0.197479  0.516129           0.407216   0.119565
# 10  0.626344    0.350840  0.532258           0.484536   0.206522
# 11  0.766129    0.871849  0.467742           0.484536   0.108696
# 12  0.852151    0.182773  0.586022           0.237113   0.456522
# ...

# %%
np.round(X_train.describe(), 1)
# Out:
#        Alcohol  Malic acid    Ash  Alcalinity of ash  Magnesium  \
# count    124.0       124.0  124.0              124.0      124.0
# mean      13.0         2.4    2.4               19.5      100.1
# std        0.8         1.1    0.3                3.6       14.7
# min       11.0         0.9    1.4               10.6       70.0
# 25%       12.4         1.6    2.2               17.1       89.0
# 50%       13.0         1.9    2.4               19.4       98.0
# 75%       13.6         3.2    2.6               21.7      106.2
# max       14.8         5.6    3.2               30.0      162.0
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count          124.0       124.0                 124.0            124.0
# mean             2.3         2.0                   0.4              1.6
# std              0.6         1.0                   0.1              0.6
# min              1.1         0.5                   0.1              0.4
# ...

# %%
plt.subplots?

# %% [markdown]
# # THIS IS DONE TO SHOW THAT Data is not lost by doing normalisation
# ## check either by scatter plot or by kdeplot

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.scatter(X_train['Alcohol'], X_train['Malic acid'], c=Y_train)
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Alcohol'], X_train_scaled['Malic acid'], c = Y_train)
ax2.set_title("After Scaling")
plt.show()

# %%
# by kdeplot
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
ax1.set_title("Before Scaling")
sns.kdeplot(X_train['Alcohol'], ax=ax1)
sns.kdeplot(X_train['Malic acid'], ax=ax1)

#after scALLING
ax2.set_title("After Scaling")
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %% [markdown]
# # Our Task is to do OneHotEncoding mam has taught label encoding

# %%
# One-hot encoding for all categorical columns
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# Display the first few rows of the encoded DataFrame
df_encoded.head()
# Out:
#    class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92      1065
# ...
